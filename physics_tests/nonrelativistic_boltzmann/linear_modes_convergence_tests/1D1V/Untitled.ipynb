# %%
import numpy as np
import pylab as pl
from IPython.display import Image
import h5py
import arrayfire as af

from physics_tests.nonrelativistic_boltzmann.run_cases import run_cases
from physics_tests.nonrelativistic_boltzmann.check_convergence import check_convergence

# %matplotlib inline

# %%
@af.broadcast
def tau_collisionless(q1, q2, p1, p2, p3):
    return(np.inf * q1**0 * p1**0)

# %%
run_cases(1, 1, -10, tau_collisionless)
check_convergence()
# Out:
# 0.001
# 0.002
# 0.003
# 0.004
# 0.005
# 0.006
# 0.007
# 0.008
# 0.009
# 0.01
# 0.011
# 0.012
# 0.013
# 0.014
# 0.015
# 0.016
# 0.017
# 0.018
# 0.019
# 0.02
# 0.021
# 0.022
# 0.023
# 0.024
# 0.025
# 0.026
# 0.027
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-b13863e98836> in <module>()
# ----> 1 run_cases(1, 1, -10, tau_collisionless)
#       2 check_convergence()
#
# ~/git_repos/Bolt/physics_tests/nonrelativistic_boltzmann/run_cases.py in run_cases(q_dim, p_dim, charge_electron, tau)
#      94         for time_index, t0 in enumerate(time_array):
#      95             print(t0)
# ---> 96             nls.strang_timestep(dt)
#      97             ls.RK4_timestep(dt)
#      98
#
# ~/git_repos/Bolt/bolt/lib/nonlinear_solver/timestep.py in strang_step(self, dt)
#     217
#     218         else:
# --> 219             op_fvm(self, dt)
#     220
#     221     # Advective Semi-lagrangian method
#
# ~/git_repos/Bolt/bolt/lib/nonlinear_solver/timestep.py in op_fvm(self, dt)
#      45         tic = af.time()
#      46
# ---> 47     fvm_timestep_RK2(self, dt)
#      48
#      49     if(self.performance_test_flag == True):
#
# ~/git_repos/Bolt/bolt/lib/nonlinear_solver/FVM_solver/timestep_df_dt.py in fvm_timestep_RK2(self, dt)
#      61                   )
#      62
# ---> 63     self.f = f_initial + df_dt_fvm(self.f, self, False) * dt
#      64
#      65     af.eval(self.f)
#
# ~/git_repos/Bolt/bolt/lib/nonlinear_solver/FVM_solver/df_dt_fvm.py in df_dt_fvm(f, self, at_n)
#      44         # Variation of q2 is along axis 2
#      45         bot_plus_eps_flux, top_minus_eps_flux = \
# ---> 46             reconstruct(self, af.broadcast(multiply, self._C_q2, f), 2, reconstruction_in_q)
#      47
#      48         if(self.physical_system.params.riemann_solver_in_q == 'lax-friedrichs'):
#
# ~/git_repos/Bolt/bolt/lib/nonlinear_solver/FVM_solver/reconstruct.py in reconstruct(self, input_array, axis, reconstruction_method)
#      19
#      20     elif(reconstruction_method == 'weno5'):
# ---> 21         left_face_value, right_face_value = reconstruct_weno5(input_array, axis)
#      22
#      23     else:
#
# ~/git_repos/Bolt/bolt/lib/nonlinear_solver/FVM_solver/reconstruction_methods/weno5.py in reconstruct_weno5(input_array, axis)
#      67     u1r =  0.375 * y0 - 1.25 * y1 + 1.875 * y2;
#      68     u2r = -0.125 * y1 + 0.75 * y2 + 0.375 * y3;
# ---> 69     u3r =  0.375 * y2 + 0.75 * y3 - 0.125 * y4;
#      70
#      71     u1l = -0.125 * y0 + 0.75 * y1 + 0.375 * y2;
#
# ~/miniconda3/lib/python3.6/site-packages/arrayfire-3.6.0-py3.6.egg/arrayfire/array.py in __rmul__(self, other)
#     883         Return other * self.
#     884         """
# --> 885         return _binary_funcr(other, self, backend.get().af_mul)
#     886
#     887     def __truediv__(self, other):
#
# ~/miniconda3/lib/python3.6/site-packages/arrayfire-3.6.0-py3.6.egg/arrayfire/array.py in _binary_funcr(lhs, rhs, c_func)
#     181     other = lhs
#     182
# --> 183     if (_is_number(lhs)):
#     184         rdims = dim4_to_tuple(rhs.dims())
#     185         lty = implicit_dtype(lhs, rhs.type())
#
# ~/miniconda3/lib/python3.6/site-packages/arrayfire-3.6.0-py3.6.egg/arrayfire/util.py in _is_number(a)
#      25
#      26 def _is_number(a):
# ---> 27     return isinstance(a, numbers.Number)
#      28
#      29 def number_dtype(a):
#
# ~/miniconda3/lib/python3.6/abc.py in __instancecheck__(cls, instance)
#     176                 print("%s: %r" % (name, value), file=file)
#     177
# --> 178     def __instancecheck__(cls, instance):
#     179         """Override for isinstance(instance, cls)."""
#     180         # Inline the cache checking
#
# KeyboardInterrupt:

# %%
Image(filename='comparison_N_032.png')

# %%
Image(filename='comparison_N_064.png')

# %%
Image(filename='comparison_N_128.png')

# %%
Image(filename='comparison_N_256.png')

# %%
Image(filename='comparison_N_512.png')
