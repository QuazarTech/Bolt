# %%
import cks.initialize as initialize
import cks.evolve as evolve
import pylab as pl
import arrayfire as af
import params
af.set_backend("cpu")

% matplotlib inline

# %%
pl.rcParams['figure.figsize']  = 12, 7.5
pl.rcParams['figure.dpi']      = 300
pl.rcParams['image.cmap']      = 'jet'
pl.rcParams['lines.linewidth'] = 1.5
pl.rcParams['font.family']     = 'serif'
pl.rcParams['font.weight']     = 'bold'
pl.rcParams['font.size']       = 20  
pl.rcParams['font.sans-serif'] = 'serif'
pl.rcParams['text.usetex']     = True
pl.rcParams['axes.linewidth']  = 1.5
pl.rcParams['axes.titlesize']  = 'medium'
pl.rcParams['axes.labelsize']  = 'medium'

pl.rcParams['xtick.major.size'] = 8     
pl.rcParams['xtick.minor.size'] = 4     
pl.rcParams['xtick.major.pad']  = 8     
pl.rcParams['xtick.minor.pad']  = 8     
pl.rcParams['xtick.color']      = 'k'     
pl.rcParams['xtick.labelsize']  = 'medium'
pl.rcParams['xtick.direction']  = 'in'    

pl.rcParams['ytick.major.size'] = 8     
pl.rcParams['ytick.minor.size'] = 4     
pl.rcParams['ytick.major.pad']  = 8     
pl.rcParams['ytick.minor.pad']  = 8     
pl.rcParams['ytick.color']      = 'k'     
pl.rcParams['ytick.labelsize']  = 'medium'
pl.rcParams['ytick.direction']  = 'in'

# %%
config = initialize.set(params)

# %%
x     = initialize.calculate_x(config)
vel_x = initialize.calculate_vel_x(config)

# %%
f_initial  = initialize.f_initial(config)
time_array = initialize.time_array(config)

# %%
class args:
    pass

args.config = config
args.f      = f_initial
args.vel_x  = vel_x
args.x      = x

# %%
data, f_final = evolve.time_integration(args, time_array)
# Out:
# Computing for Time =  0.005
# Computing for Time =  0.055
# Computing for Time =  0.105
# Computing for Time =  0.155
# Computing for Time =  0.205
# Computing for Time =  0.255
# Computing for Time =  0.305
# Computing for Time =  0.355
# Computing for Time =  0.405
# Computing for Time =  0.455
# Computing for Time =  0.505
# Computing for Time =  0.555
# Computing for Time =  0.605
# Computing for Time =  0.655
# Computing for Time =  0.705
# Computing for Time =  0.755
# Computing for Time =  0.805
# Computing for Time =  0.855
# Computing for Time =  0.905
# Computing for Time =  0.955
# Computing for Time =  1.005
# Computing for Time =  1.055
# Computing for Time =  1.105
# Computing for Time =  1.155
# Computing for Time =  1.205
# Computing for Time =  1.255
# Computing for Time =  1.305
# Computing for Time =  1.355
# Computing for Time =  1.405
# Computing for Time =  1.455
# Computing for Time =  1.505
# Computing for Time =  1.555
# Computing for Time =  1.605
# Computing for Time =  1.655
# Computing for Time =  1.705
# Computing for Time =  1.755
# Computing for Time =  1.805
# Computing for Time =  1.855
# Computing for Time =  1.905
# Computing for Time =  1.955

# %%
pl.plot(time_array, data)
pl.xlabel('Time')
pl.ylabel(r'$MAX(\delta \rho(x))$')
